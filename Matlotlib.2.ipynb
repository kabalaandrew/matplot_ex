# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D 
# %matplotlib inline
plt.style.use('ggplot')

# %%
ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.head()
ts.plot()

# %%
plt.figure(); ts.plot(style='k--', label='Series'); plt.legend()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df.head(3)
# Out:
#                    A         B         C         D
# 2000-01-01 -1.150848  0.955752  1.947363 -0.327476
# 2000-01-02 -0.053599  0.997511  0.704264 -0.611539
# 2000-01-03 -1.039072 -1.507245  0.325643 -0.101594

# %%
df = df.cumsum()
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -1.150848  0.955752  1.947363 -0.327476
# 2000-01-02 -1.204447  1.953263  2.651627 -0.939015
# 2000-01-03 -2.243519  0.446019  2.977270 -1.040609
# 2000-01-04 -2.101676  0.288261  4.491463 -0.217621
# 2000-01-05 -2.756058  0.164674  3.854595  0.941420

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
#Plotting each axis on a different plot
df.plot(subplots=True, figsize=(6, 6)); plt.legend(loc='best')

# %%
#log y scale
plt.figure();
ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

ts = np.exp(ts.cumsum())

ts.plot(logy=True)

# %%
df2 = DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot(kind='bar');
plt.legend(loc='best')

# %%
df2.plot(kind='barh', stacked=True);

# %%
plt.figure();
df['A'].diff().hist()

# %%
plt.figure()
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DCA1F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DEDAF28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E07BA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E11E898>]], dtype=object)

# %%
df = DataFrame(np.random.rand(10,5))
print df.head()
plt.figure();
bp = df.boxplot()
# Out:
#           0         1         2         3         4
# 0  0.920559  0.534443  0.889970  0.820849  0.292212
# 1  0.735289  0.301588  0.932484  0.811977  0.146514
# 2  0.256463  0.753063  0.883059  0.622286  0.795527
# 3  0.193543  0.481985  0.989714  0.981691  0.005921
# 4  0.430132  0.659909  0.642363  0.939544  0.332084
# C:\Users\USER\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.

# %%
plt.style.use('seaborn-darkgrid')
df = DataFrame(np.random.rand(10,2), columns=['Col1', 'Col2'] )
df['X'] = Series(['A','A','A','A','A','B','B','B','B','B'])
print df.head()
plt.figure();
bp = df.boxplot(by='X')
# Out:
#        Col1      Col2  X
# 0  0.522970  0.228177  A
# 1  0.937549  0.951386  A
# 2  0.719154  0.935788  A
# 3  0.094898  0.356007  A
# 4  0.526128  0.667670  A
